# %% [markdown]
# <a href="https://colab.research.google.com/github/Bandanagiri/Bandanagiri/blob/main/Lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implement K-means clust

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import numpy as np

# %%
from sklearn.datasets import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50,color='blue');

# %% [markdown]
# Import K_Means from SKlearn and Fit the data

# %%
list(X.shape)
# Out:
# [300, 2]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4, n_init=10)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %% [markdown]
# Visualize the fitted data by coloring the blobs by assigned list item list item label numbers

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
centers=kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1],c='black', s=200, alpha=0.5);

# %% [markdown]
# How many number of Clusters

# %% [markdown]
# plot the clusters formed using scatter plot

# %%
labels = KMeans(10, random_state=0, n_init=10).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,  s=50, cmap='viridis');

# %% [markdown]
# Limitations of K-Means Algorithm

# %%
from sklearn.datasets import make_moons
X, y = make_moons(200, noise=.05, random_state=0)

# %%
labels=KMeans(2, random_state=0, n_init=10).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis');

# %% [markdown]
# Kernel Transformation

# %%
from sklearn.cluster import SpectralClustering
model=SpectralClustering(n_clusters=2,affinity='nearest_neighbors',assign_labels='kmeans')
labels=model.fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
labels=model.fit_predict(X)
plt.scatter(X[:,0],X[:,1],c=labels,s=50,cmap='viridis')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
